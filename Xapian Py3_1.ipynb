# %%
import spacy
import os
import xapian
import re
import io
import shutil
import datetime
from tqdm import tqdm as tqdm

# %%
dbpath = 'xapIndex_SenID_Text'
datapath = 'wiki-pages-text/'

# %% [markdown]
# # Shard Paths

# %%
filesInDataPath = sorted([datapath + fileName for fileName in os.listdir(datapath)], reverse=True)
filesInDataPath = sorted(filesInDataPath)

# %%
assert(filesInDataPath[0]=='wiki-pages-text/wiki-001.txt')

# %% [markdown]
# Xapian build Index

# %%
x_db = xapian.WritableDatabase(dbpath, xapian.DB_CREATE_OR_OPEN)

# %% [markdown]
# Set termgenerator for indexing

# %%
index = xapian.TermGenerator()

# %% [markdown]
# Set Stemmer

# %%
index.set_stemmer(xapian.Stem('en'))

# %% [markdown]
# Build Index

# %%
indexCounter = 0
print('Time started at', datetime.datetime.now().time())
with tqdm(total=len(filesInDataPath)) as pbar:
    for shardFile in filesInDataPath:
        with open(shardFile, 'r') as openedFile:
            print('Now processing:', shardFile)
            for line in openedFile:
                indexCounter += 1
                # Processing line
                docID, sentenceID, text = line.split(' ', 2)
                try:
                    sentenceID = int(sentenceID)
                except Exception:
                    pass
                xapianDoc = xapian.Document()
                xapianDoc.set_data(text + ',,,' + docID +',,,' + str(sentenceID))
                index.set_document(xapianDoc)
                index.index_text(text)
                index.increase_termpos()
                x_db.replace_document(indexCounter, xapianDoc)
        x_db.commit()
        pbar.update(1)
x_db.close()

# %% [markdown]
# Check DB statistics

# %%
# !xapian-delve $dbpath
# Out:
# UUID = aec569e4-d627-4bcd-91f6-b56749d28c15
# number of documents = 25248397
# average document length = 35.7647
# document length lower bound = 1
# document length upper bound = 7800
# highest document id ever used = 25248397
# has positional information = true

# %% [markdown]
# Search DB

# %%
TOP_RESULTS_LIMIT = 15

# %%
def search(dbpath, querystring, offset=0, pagesize=10):
    
    database = xapian.Database(dbpath)
    enquire = xapian.Enquire(database)
    query_string = querystring

    qp = xapian.QueryParser()
    stemmer = xapian.Stem("english")
    qp.set_stemmer(stemmer)
    qp.set_database(database)
    
    qp.set_stemming_strategy(xapian.QueryParser.STEM_SOME)
    query = qp.parse_query(query_string)
    #print "Parsed query is: %s" % str(query)

    # Find the top results for the query.
    enquire.set_query(query)
    matches = enquire.get_mset(0, TOP_RESULTS_LIMIT)

    # Display the results.
    #print(%i results found." % matches.get_matches_estimated()
    #print "Results 1-%i:" % matches.size()
    
    text_dictionary = {}
    for m in matches:
        print('RANK:', m.rank + 1)
        print('PERCENTAGE MATCH:', m.percent)
        print('DOC ID:', m.docid)
        print('DOC TXT:', m.document.get_data())
        decoded_text = m.document.get_data().decode('utf-8')
        text_dictionary[(decoded_text.split(",,,")[1],decoded_text.split(",,,")[2])] =decoded_text.split(",,,")[0]
                                                                                  

    return text_dictionary

# %%
# %%time
query = "When in rome do as romans do"
matches = search(dbpath, query)
# Out:
# RANK: 1
# PERCENTAGE MATCH: 100
# DOC ID: 24496184
# RANK: 12
# PERCENTAGE MATCH: 64
# DOC ID: 17574492
# DOC TXT: b'Peace Thru Vandalism / When in Rome Do as The Vandals is a compilation album by the southern California punk rock band The Vandals .\n,,,Peace_Thru_Vandalism_/_When_in_Rome_Do_as_The_Vandals,,,0'
# RANK: 13
# PERCENTAGE MATCH: 62
# DOC ID: 20901238
# DOC TXT: b"Paul the Apostle refers to this sin directly when he states `` For I do not do the good I want ... '' -LRB- Romans -RRB- .\n,,,Sin_of_omission,,,11"
# RANK: 14
# PERCENTAGE MATCH: 62
# DOC ID: 17409172
# DOC TXT: b"The EP was re-released by Time Bomb Recordings in 1989 as a CD that also included the band 's first LP , When in Rome Do as the Vandals .\n,,,Peace_thru_Vandalism,,,2"
# RANK: 15
# PERCENTAGE MATCH: 62
# DOC ID: 18694005
# DOC TXT: b'\xe2\x80\xa2 A writing by Sylvester , Bishop of Rome , having to do with the conversion of the Roman Emperor Constantine to Christianity\n,,,Pseudo-Zacharias_Rhetor,,,11'
# CPU times: user 139 ms, sys: 401 ms, total: 540 ms
# Wall time: 911 ms

# %%
import pandas as pd

feature_db = pd.DataFrame({"claim": query_list,"evidence":tuple(matches.keys())})
feature_db
#.split("\n,,,")[1].split(",,,")[0]
# Out:
#                            claim  \
# 0   When in rome do as romans do
# 1   When in rome do as romans do
# 2   When in rome do as romans do
# 3   When in rome do as romans do
# 4   When in rome do as romans do
# 5   When in rome do as romans do
# 6   When in rome do as romans do
# 7   When in rome do as romans do
# 8   When in rome do as romans do
# 9   When in rome do as romans do
# 10  When in rome do as romans do
# 11  When in rome do as romans do
# 12  When in rome do as romans do
# 13  When in rome do as romans do
# 14  When in rome do as romans do
#
#                                              evidence
# 0                                   (When_in_Rome, 3)
# 1              (When_in_Rome,_do_as_the_Romans_do, 6)
# 2              (When_in_Rome,_do_as_the_Romans_do, 0)
# 3                 (When_in_Rome_Do_as_The_Vandals, 0)
# 4                                    (Greta_Rana, 11)
# 5                           (Peace_thru_Vandalism, 3)
# 6                                     (Anapodoton, 5)
# 7              (When_in_Rome,_do_as_the_Romans_do, 5)
# 8                                    (Roman_Party, 1)
# 9     (No_Apologies_-LRB-The_Eyeliners_album-RRB-, 1)
# 10                   (Hocus_Pocus_-LRB-song-RRB-, 11)
# 11  (Peace_Thru_Vandalism_/_When_in_Rome_Do_as_The...
# 12                              (Sin_of_omission, 11)
# 13                          (Peace_thru_Vandalism, 2)
# 14                      (Pseudo-Zacharias_Rhetor, 11)

# %%
feature_db['average_word_length'] = feature_db['claim'].apply(lambda x: (len(x)/len(x.split(' '))))
feature_db
# Out:
#                            claim  \
# 0   When in rome do as romans do
# 1   When in rome do as romans do
# 2   When in rome do as romans do
# 3   When in rome do as romans do
# 4   When in rome do as romans do
# 5   When in rome do as romans do
# 6   When in rome do as romans do
# 7   When in rome do as romans do
# 8   When in rome do as romans do
# 9   When in rome do as romans do
# 10  When in rome do as romans do
# 11  When in rome do as romans do
# 12  When in rome do as romans do
# 13  When in rome do as romans do
# 14  When in rome do as romans do
#
#                                              evidence  average_word_length
# 0                                   (When_in_Rome, 3)                  4.0
# 1              (When_in_Rome,_do_as_the_Romans_do, 6)                  4.0
# 2              (When_in_Rome,_do_as_the_Romans_do, 0)                  4.0
# 3                 (When_in_Rome_Do_as_The_Vandals, 0)                  4.0
# 4                                    (Greta_Rana, 11)                  4.0
# 5                           (Peace_thru_Vandalism, 3)                  4.0
# 6                                     (Anapodoton, 5)                  4.0
# 7              (When_in_Rome,_do_as_the_Romans_do, 5)                  4.0
# 8                                    (Roman_Party, 1)                  4.0
# 9     (No_Apologies_-LRB-The_Eyeliners_album-RRB-, 1)                  4.0
# 10                   (Hocus_Pocus_-LRB-song-RRB-, 11)                  4.0
# 11  (Peace_Thru_Vandalism_/_When_in_Rome_Do_as_The...                  4.0
# 12                              (Sin_of_omission, 11)                  4.0
# 13                          (Peace_thru_Vandalism, 2)                  4.0
# 14                      (Pseudo-Zacharias_Rhetor, 11)                  4.0

# %%
def jaccard_coefficient(claim,evidence_list):
    intersection = len(list(set(claim).intersection(evidence_list)))
    print(list(set(claim).intersection(evidence_list)))
    union = (len(claim) + len(evidence_list)) - intersection
    return (1 - float(intersection / union))

# %%
feature_db['jaccard_similarity'] = list(map(lambda x,y: jaccard_coefficient(x,list(y)),feature_db['claim'],matches.values()))
# Out:
# ['i', 'o', 'm', ' ', 'W', 's', 'r', 'n', 'd', 'a', 'e', 'h']
# ['i', 'o', 'm', ' ', 'W', 's', 'r', 'n', 'd', 'a', 'e', 'h']
# ['i', 'o', 'm', ' ', 'W', 's', 'r', 'n', 'd', 'a', 'e', 'h']
# ['i', 'o', 'm', ' ', 'W', 's', 'r', 'n', 'd', 'a', 'e', 'h']
# ['i', 'o', 'm', ' ', 'W', 's', 'r', 'n', 'd', 'a', 'e', 'h']
# ['i', 'o', 'm', ' ', 'W', 's', 'r', 'n', 'd', 'a', 'e', 'h']
# ['i', 'o', 'm', ' ', 'W', 's', 'r', 'n', 'd', 'a', 'e', 'h']
# ['o', 'i', 'm', ' ', 'W', 's', 'r', 'n', 'd', 'a', 'e', 'h']
# ['i', 'o', 'm', ' ', 's', 'r', 'n', 'd', 'a', 'e', 'h']
# ['i', 'o', 'm', ' ', 'W', 's', 'r', 'n', 'd', 'a', 'e', 'h']
# ['o', 'i', 'm', ' ', 'W', 's', 'r', 'n', 'd', 'a', 'e', 'h']
# ['i', 'o', 'm', ' ', 'W', 's', 'r', 'n', 'd', 'a', 'e', 'h']
# ['o', 'i', 'm', ' ', 's', 'r', 'n', 'd', 'a', 'e', 'h']
# ['i', 'o', 'm', ' ', 'W', 's', 'r', 'n', 'd', 'a', 'e', 'h']
# ['i', 'o', 'm', ' ', 's', 'r', 'n', 'd', 'a', 'e', 'h']

# %%
import warnings
warnings.filterwarnings('ignore')
feature_db
# Out:
#                            claim  \
# 0   When in rome do as romans do
# 1   When in rome do as romans do
# 2   When in rome do as romans do
# 3   When in rome do as romans do
# 4   When in rome do as romans do
# 5   When in rome do as romans do
# 6   When in rome do as romans do
# 7   When in rome do as romans do
# 8   When in rome do as romans do
# 9   When in rome do as romans do
# 10  When in rome do as romans do
# 11  When in rome do as romans do
# 12  When in rome do as romans do
# 13  When in rome do as romans do
# 14  When in rome do as romans do
#
#                                              evidence  average_word_length  \
# 0                                   (When_in_Rome, 3)                  4.0
# 1              (When_in_Rome,_do_as_the_Romans_do, 6)                  4.0
# 2              (When_in_Rome,_do_as_the_Romans_do, 0)                  4.0
# 3                 (When_in_Rome_Do_as_The_Vandals, 0)                  4.0
# 4                                    (Greta_Rana, 11)                  4.0
# 5                           (Peace_thru_Vandalism, 3)                  4.0
# 6                                     (Anapodoton, 5)                  4.0
# 7              (When_in_Rome,_do_as_the_Romans_do, 5)                  4.0
# 8                                    (Roman_Party, 1)                  4.0
# 9     (No_Apologies_-LRB-The_Eyeliners_album-RRB-, 1)                  4.0
# 10                   (Hocus_Pocus_-LRB-song-RRB-, 11)                  4.0
# 11  (Peace_Thru_Vandalism_/_When_in_Rome_Do_as_The...                  4.0
# 12                              (Sin_of_omission, 11)                  4.0
# 13                          (Peace_thru_Vandalism, 2)                  4.0
# 14                      (Pseudo-Zacharias_Rhetor, 11)                  4.0
#
#     jaccard_similarity                                   spacy_similarity
# 0             0.869565  [0.1127464875765488, 0.1127464875765488, 0.172...
# 1             0.891892  [0.43955122683169295, 0.128560090572638, 0.051...
# 2             0.960000  [0.4589058202202472, 0.128560090572638, 0.1224...
# 3             0.967213  [0.4589058202202472, 0.128560090572638, 0.1224...
# 4             0.956835  [0.3149799664281064, 0.2798722897597501, 0.051...
# 5             0.876289  [0.43955122683169295, 0.128560090572638, 0.122...
# 6             0.946903  [0.3149799664281064, 0.12405169137778345, 0.17...
# 7             0.925466  [0.43955122683169295, 0.128560090572638, 0.122...
# 8             0.960714  [0.3149799664281064, 0.16262031465318408, 0.17...
# 9             0.923567  [0.23479753925819682, 0.23862515052215402, 0.1...
# 10            0.912409  [0.43955122683169295, 0.128560090572638, 0.122...
# 11            0.919463  [0.38096696980092926, 0.12247122522584558, 0.0...
# 12            0.921429  [0.38096696980092926, 0.05196985430490302, 0.2...
# 13            0.922078  [0.43955122683169295, 0.128560090572638, 0.122...
# 14            0.923077  [0.0500609534784563, 0.1721324828701981, 0.314...

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
def spacy_similarity(sentence1, sentence_list):
    s1 = nlp(sentence1)
    similarity_scores = []
    for sentence in sentence_list:
        s2 = nlp(sentence)
        similarity_scores.append(s1.similarity(s2))
    return similarity_scores

# %%
feature_db['spacy_similarity'] = list(map(lambda x,y: spacy_similarity(x,y),feature_db['claim'],matches.values()))
feature_db['spacy_similarity']
# Out:
# 0     [0.1127464875765488, 0.1127464875765488, 0.172...
# 1     [0.43955122683169295, 0.128560090572638, 0.051...
# 2     [0.4589058202202472, 0.128560090572638, 0.1224...
# 3     [0.4589058202202472, 0.128560090572638, 0.1224...
# 4     [0.3149799664281064, 0.2798722897597501, 0.051...
# 5     [0.43955122683169295, 0.128560090572638, 0.122...
# 6     [0.3149799664281064, 0.12405169137778345, 0.17...
# 7     [0.43955122683169295, 0.128560090572638, 0.122...
# 8     [0.3149799664281064, 0.16262031465318408, 0.17...
# 9     [0.23479753925819682, 0.23862515052215402, 0.1...
# 10    [0.43955122683169295, 0.128560090572638, 0.122...
# 11    [0.38096696980092926, 0.12247122522584558, 0.0...
# 12    [0.38096696980092926, 0.05196985430490302, 0.2...
# 13    [0.43955122683169295, 0.128560090572638, 0.122...
# 14    [0.0500609534784563, 0.1721324828701981, 0.314...
# Name: spacy_similarity, dtype: object

# %%
import pandas as pd
evidence_df = pd.DataFrame(matches).transpose().reset_index()

# %%
#evidence_df = evidence_df.reset_index()
evidence_df.columns = ["index","text"]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-cb066339e17c> in <module>
# ----> 1 evidence_df.iloc[0]["text"].split("\n,,,")[1]
#
# TypeError: a bytes-like object is required, not 'str'
